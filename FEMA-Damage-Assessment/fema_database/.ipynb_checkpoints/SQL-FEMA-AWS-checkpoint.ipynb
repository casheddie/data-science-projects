# %% [markdown]
# ## This notebook outlines the requirements for establishing connection to AWS RDS database.  The remote database in AWS is running a MySQL instance.

# %%
# Import the necessary libraries

from flask import Flask
from flask_sqlalchemy import SQLAlchemy
import pandas as pd
from sqlalchemy import create_engine

# Creates connection to the AWS RDS database.  Real username and password have been removed.
# Substitute your real username and password of your database instance in AWS below.
engine = create_engine('mysql+pymysql://username:password@fema-prob6-db1.cdpk6lrtfnoa.us-east-1.rds.amazonaws.com:3306/FEMA_DB')

# %%
# Main query code for selelcting items from database
sql = """
SELECT * from assessment_report

"""
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# Empty DataFrame
# Columns: [assessment_id, address, zillow_id, home_type, year_built, lot_size, living_area, num_bathrooms, num_bedrooms, last_sold_time, last_sold_price, zestimate_price, before_image, after_image, disater_type, damge_degree, occupancy_status, rent_status, property_access, additional notes]
# Index: []

# %%
# This code does the initial load into the database.  These addresses are made up and here for example. 
df = pd.read_csv('fema_claim_reports.csv')

# %%
# Show the first few rows of database. 
df.head()
# Out:
#    assessment_id                                            address  \
# 0            NaN                123 main street, Anytown, NY, 01193
# 1            NaN             700 Falls Lake Drive, Bowiel, MD 20721
# 2            NaN  600 Water Island  Road, Falls Church, Iowa, 75463
#
#    zillow_id      home_type  year_built  lot_size  living_area  num_bathrooms  \
# 0   23456663  single family        2010     10004         3500            3.5
# 1   44586754  single family        1996     12500         4000            4.0
# 2   55652345      town home        2017      2000         1543            1.5
#
#    num_bedrooms  last_sold_time  last_sold_price  zestimate_price  \
# 0             6            2015           350000           500000
# 1             8            1998           218000           495000
# 2             3            1990            65000           150000
#
#    before_image  after_image disater_type  damge_degree occupancy_status  \
# ...

# %%
# This code writes the dataframe to remote database.  The code gives an error now because I removed login information
# to the live dastabase for security purposes.
df.to_sql('assessment_report',con=engine, index=False, if_exists='append')
# Out:
# --------------------------------------------------------------------------
# OperationalError                         Traceback (most recent call last)
# /anaconda3/envs/dsi/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# /anaconda3/envs/dsi/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# /anaconda3/envs/dsi/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# /anaconda3/envs/dsi/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
# ...
